# %% [markdown]
# **Gestión de cuentas del baco de la nación**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Defino una cuenta con el nombre de "c_72300935", ingreso el número de cuenta y el saldo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Al usar el método Depositar, coloco un monto negativo y aparece ValueError

# %% [markdown]
# ![Captura de pantalla 2024-10-20 190245.png](data:image/png;base64,...)

# %% [markdown]
# Uso el método Retirar y coloco una cantidad menor a la de la cuenta, por lo cual se ejecuta sin problema. Pero si coloco una cantiad superior a la poseída en la cuenta, me aparece Value Error de nuevo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# La parte más difícil fue el investigar y entender las "excepciones". Tanto except como raise. Después de haber practicado con el código de la tarea de la semana pasada, me pareció más fácil el completar este.
